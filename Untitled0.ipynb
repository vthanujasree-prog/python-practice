# %%
sum=5+2
divi=5/2
mul=5*2
power=5**2
print(type(sum))
print(type(divi))
print(type(mul))
print(type(power))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>

# %%
x="10"
y=5
result1=int(x)+y
print(result1)
print(type(result1))
result2=x+str(5)
print(result2)
print(type(result2))
# Out:
# 15
# <class 'int'>
# 105
# <class 'str'>

# %%
boolean=True
print(True+True)
boolean=False
print(False+10)
# Out:
# 2
# 10
