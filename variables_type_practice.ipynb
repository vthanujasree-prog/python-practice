# %%
print(book['title'])
print(book['author'])
print(book['year'])
print(book['is_available'])
# Out:
# python
# guidovanrossum
# 1991
# yes

# %%
book={"title":"python","author":"guidovanrossum","year":1991,"is_available":"yes"}
for key,uvalue in book.items():
    print(key,":",value)
# Out:
# title : python
# author : guidovanrossum
# year : 1991
# is_available : yes
